# %%
from pyaltim.portals.hydroweb import HydrowebConnect
import shapely
import pandas as pd
# Out:
# /usr/lib/python3.12/site-packages/pyproj/__init__.py:91: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_DATA (PROJ 9.1+) | PROJ_LIB (PROJ<9.1) or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))

# %% [markdown]
# ## Case: Lake Tana

# %% [markdown]
# ##### Load the polygon for Lake Tana as a shapely object
# A Geojson file of any area can be developed using this webapp: https://geojson.io/#map=9.35/24.5561/89.6891

# %%
with open('Data/Lake_Tana.geojson','rb') as fid:
    tanapoly=shapely.from_geojson(fid.read())

display(tanapoly)
# Out:
# <GEOMETRYCOLLECTION (POLYGON ((37.234 12.238, 37.17 12.342, 37 12.289, 36.84...>

# %% [markdown]
# ##### Create a connection manager for Dahiti

# %%
# retrieve the current catalogue of station listings
hwcon=HydrowebConnect("HYDROWEB_LAKES_OPE")
hwtargets=hwcon.get_items(tanapoly)
# Out:
# Please enter apikey for hydroweb next (theia) ········

# %%
#get the actual data (assets)
info,dstana=hwcon.get_asset(hwtargets.item_id[0])
# display(dstana)
dstana['time']=pd.to_datetime(dstana.time)

# %%
dstana.water_level.plot()

# %% [markdown]
# ## Case: Ganges - Brahmaputra - Meghna (GBM) Confluence

# %%
with open('Data/GBM_Basin.geojson','rb') as fid:
    gbmpoly=shapely.from_geojson(fid.read())

display(gbmpoly)
# Out:
# <GEOMETRYCOLLECTION (POLYGON ((89.895 22.508, 91.279 22.78, 90.887 23.44, 90...>

# %%
hwcon=HydrowebConnect("HYDROWEB_RIVERS_OPE")
gbmtargets=hwcon.get_items(gbmpoly)
display(gbmtargets)
# Out:
# Please enter apikey for hydroweb next (theia) ········
#                       tstart                      tend  \
# 2  2016-05-01 04:13:00+00:00 2024-11-27 04:14:00+00:00
# 3  2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 5  2018-12-19 15:44:00+00:00 2024-12-14 15:45:00+00:00
# 6  2018-12-19 15:44:00+00:00 2024-12-14 15:44:00+00:00
# 7  2023-07-27 23:18:00+00:00 2024-12-09 17:20:00+00:00
# 9  2018-12-12 04:15:00+00:00 2024-12-07 04:16:00+00:00
# 10 2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 11 2023-07-27 23:18:00+00:00 2024-12-09 17:20:00+00:00
# 13 2020-07-05 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 14 2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 16 2008-07-21 01:25:00+00:00 2024-12-13 02:37:00+00:00
# 18 2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 19 2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 20 2016-05-08 15:42:00+00:00 2024-12-04 15:42:00+00:00
# 24 2016-05-01 04:14:00+00:00 2024-11-27 04:14:00+00:00
# 25 2016-05-01 04:14:00+00:00 2024-11-27 04:14:00+00:00
# 26 2020-07-08 15:44:00+00:00 2024-12-14 15:45:00+00:00
# 28 2016-05-08 15:42:00+00:00 2024-12-04 15:42:00+00:00
# 32 2018-12-16 04:12:00+00:00 2024-12-11 04:13:00+00:00
# 33 2018-12-08 04:19:00+00:00 2024-12-03 04:20:00+00:00
# 34 2016-08-20 15:46:00+00:00 2024-11-30 15:46:00+00:00
# 35 2016-05-01 04:14:00+00:00 2024-11-27 04:14:00+00:00
# 38 2023-07-27 23:18:00+00:00 2024-12-09 17:20:00+00:00
# 39 2023-07-27 23:18:00+00:00 2024-12-09 17:20:00+00:00
# 40 2016-03-08 04:13:00+00:00 2024-11-27 04:14:00+00:00
# 41 2023-07-27 23:18:00+00:00 2024-12-09 17:20:00+00:00
#
#                                               item_id  \
# 2   R_GANGES-BRAHMAPUTRA_KARNATALI_KM0090@hysope2:...
# 3   R_GANGES-BRAHMAPUTRA_MEGHNAA-NDII_KM0035@hysop...
# 5   R_GANGES-BRAHMAPUTRA_KIRTANKHOLA-TRIB01_KM0052...
# 6   R_GANGES-BRAHMAPUTRA_KIRTANKHOLA_KM0044@hysope...
# 7   R_GANGES-BRAHMAPUTRA_KIRTANKHOLA-TRIB01_KM0030...
# 9   R_GANGES-BRAHMAPUTRA_PADMA_KM0110@hysope2:d3f5...
# 10  R_GANGES-BRAHMAPUTRA_BISHKHALI-TRIB01_KM0045@h...
# 11  R_GANGES-BRAHMAPUTRA_PADMA_KM0052@hysope2:b7be...
# 13  R_GANGES-BRAHMAPUTRA_MEGHNAA-NDII_KM0037@hysop...
# 14  R_GANGES-BRAHMAPUTRA_MEGHNA_KM0058@hysope2:a5d...
# 16  R_GANGES-BRAHMAPUTRA_PADMA_KM0167@hysope2:9024...
# 18  R_GANGES-BRAHMAPUTRA_MEGHNAA-NDII_KM0056@hysop...
# 19  R_GANGES-BRAHMAPUTRA_BISHKHALI-TRIB01_KM0030@h...
# 20  R_GANGES-BRAHMAPUTRA_SHITALAKSHYA_KM0071@hysop...
# 24  R_GANGES-BRAHMAPUTRA_BHAIRAB-TRIB01_KM0035@hys...
# 25  R_GANGES-BRAHMAPUTRA_PALONG-TRIB01_KM0045@hyso...
# 26  R_GANGES-BRAHMAPUTRA_PALONG_KM0035@hysope2:5d0...
# 28  R_GANGES-BRAHMAPUTRA_MEGHNAA-NDII_KM0023@hysop...
# 32  R_GANGES-BRAHMAPUTRA_GANGES_KM0020@hysope2:3d7...
# 33  R_GANGES-BRAHMAPUTRA_PADMA_KM0220@hysope2:3801...
# 34  R_GANGES-BRAHMAPUTRA_PADMA_KM0138@hysope2:36e2...
# 35  R_GANGES-BRAHMAPUTRA_PADMA_KM0054@hysope2:35c2...
# 38  R_GANGES-BRAHMAPUTRA_BONGSHAI_KM0077@hysope2:2...
# 39  R_GANGES-BRAHMAPUTRA_PALONG-TRIB01_KM0042@hyso...
# 40  R_GANGES-BRAHMAPUTRA_TURAG_KM0102@hysope2:17e3...
# 41  R_GANGES-BRAHMAPUTRA_KIRTANKHOLA-TRIB01_KM0035...
#
#                      geometry
# 2   POINT (90.29680 23.80550)
# 3   POINT (90.64700 23.33800)
# 5   POINT (90.28610 22.80810)
# 6   POINT (90.32230 22.66230)
# 7   POINT (90.03660 22.60680)
# 9   POINT (89.81410 23.75890)
# 10  POINT (90.51300 22.80070)
# 11  POINT (90.20170 23.49670)
# 13  POINT (90.68480 23.48870)
# 14  POINT (90.55760 22.97930)
# 16  POINT (89.32360 23.91810)
# 18  POINT (90.70910 23.58540)
# 19  POINT (90.49400 22.72390)
# 20  POINT (90.51310 23.77540)
# 24  POINT (90.01520 22.67860)
# 25  POINT (90.13500 23.15950)
# 26  POINT (90.19600 23.16980)
# 28  POINT (90.62860 23.30890)
# 32  POINT (90.62090 23.23330)
# 33  POINT (88.98140 24.15030)
# 34  POINT (89.56490 23.80910)
# 35  POINT (90.20910 23.47260)
# 38  POINT (90.31610 24.10260)
# 39  POINT (90.13910 23.16110)
# 40  POINT (90.34420 23.99400)
# 41  POINT (90.05380 22.67650)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

ax=plt.axes(projection=ccrs.PlateCarree())
gbmtargets.plot(ax=ax)
ax.coastlines()
ax.add_feature(cfeature.RIVERS, zorder=1, edgecolor='b')
